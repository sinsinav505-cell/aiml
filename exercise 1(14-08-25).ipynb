# %%
a=int(input("Enter a value:"))
b=float(input("Enter a value:"))
c=complex(input("Enter a value:"))
print(a,b,c)
print(a-b)
print(a+c)
print(a*b)
print(a/b)
# Out:
# Enter a value:2
# Enter a value:2.7
# Enter a value:4j
# 2 2.7 4j
# -0.7000000000000002
# (2+4j)
# 5.4
# 0.7407407407407407

# %%
d1={"name":"Sinsina","age":20,"place":"Kannur"}
print(d1)
del d1["name"]
print(d1)
d1["name"]="Sin"
print(d1)
d1.update({"name":"Sinu"})
print(d1)
d1.pop("name")
print(d1)
d2=d1.copy()
print(d2)
d1.clear()
print(d1)
# Out:
# {'name': 'Sinsina', 'age': 20, 'place': 'Kannur'}
# {'age': 20, 'place': 'Kannur'}
# {'age': 20, 'place': 'Kannur', 'name': 'Sin'}
# {'age': 20, 'place': 'Kannur', 'name': 'Sinu'}
# {'age': 20, 'place': 'Kannur'}
# {'age': 20, 'place': 'Kannur'}
# {}

# %%
d2={"name":"Sin","Age":20}
for key in d2:
  print(key)
# Out:
# name
# Age

# %%
d2={"name":"Sin","Age":20}
for value in d2.values():
  print(value)
# Out:
# Sin
# 20

# %%
d2={"name":"sin","age":20}
for key,value in d2.items():
  print(key,value)
# Out:
# name sin
# age 20

# %%
l1=[4,2,3,1]
print(l1)
l2=l1.copy()
print(l2)
l1.sort()
print(l1)
l1.reverse()
print(l1)
l1.remove(3)
print(l1)
l1.append(5)
print(l1)
l1.pop(1)
print(l1)
l2=[5,8,9,0]
l1.extend(l2)
print(l1)
l1.clear()
print(l1)
# Out:
# [4, 2, 3, 1]
# [4, 2, 3, 1]
# [1, 2, 3, 4]
# [4, 3, 2, 1]
# [4, 2, 1]
# [4, 2, 1, 5]
# [4, 1, 5]
# [4, 1, 5, 5, 8, 9, 0]
# []

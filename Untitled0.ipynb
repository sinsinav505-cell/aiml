# %%
a = int(input("Enter new number"))
b = int(input("Enter new number"))
c = int(input("Enter new number"))
if a<b and c<b:
  print("Hello")
else:
  print("Welcome")
# Out:
# Enter new number100
# Enter new number2000
# Enter new number300
# Hello

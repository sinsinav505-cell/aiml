# %%
t1=(1,2,3,4,5)
t2=t1
print(t2)
print(len(t1))
t1.index(4)
# Out:
# (1, 2, 3, 4, 5)
# 5
# 3

# %%
s1={1,2,3,4,5}
print(s1)
print(len(s1))
s2={5,6,7,8,9}
a=s1|s2
print(a)
b=s1&s2
print(b)
c=s1-s2
print(c)
# Out:
# {1, 2, 3, 4, 5}
# 5
# {1, 2, 3, 4, 5, 6, 7, 8, 9}
# {5}
# {1, 2, 3, 4}

# %%
s1={4,5,6,7}
print(2 in s1)
print(2 not in s1)
# Out:
# False
# True

# %%
def add(a,b):
  sum=(a+b)
  print(sum)
add(5,5)
# Out:
# 10

# %%
a=int(input("Enter A:"))
if a>10:
  print("a is greater")
else:
  print("a is lesser")
# Out:
# Enter A:20
# a is greater

# %%
a=int(input("Enter A:"))
b=int(input("Enter B:"))
if a<b:
  print("A less than B")
elif a>b:
  print("A greater than B")
else:
  print("A and B are equal")
# Out:
# Enter A:10
# Enter B:50
# A less than B

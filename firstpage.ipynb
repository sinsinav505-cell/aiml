# %%
x=10
y=-200
z=0
print(x,y,z)
# Out:
# 10 -200 0

# %%
x=10
y=2.35
z=0
print(x,y,z)
# Out:
# 10 2.35 0

# %%
w=3+4j
x=-1.5+2.5j
y=2-3.3j
z=-1j
print(w,x,y,z)
# Out:
# (3+4j) (-1.5+2.5j) (2-3.3j) (-0-1j)

# %%
print(5+2)
# Out:
# 7

# %%
print('sum=',5+2)
# Out:
# sum= 7

# %%
a=int(input("Enter a"))
b=int(input("Enter b"))
print("sum=",a+b)
# Out:
# Enter a2
# Enter b2
# sum= 4

# %%
print(2>=3)
print(3<=3)
print(3!=4)
# Out:
# False
# True
# True

# %%
print("Sinsina")
# Out:
# Sinsina

# %%
n=str(input("What is my name"))
print(n)
# Out:
# What is my nameSinsina
# Sinsina

# %%
my_dict={"name":"Sinsina","Age":20,"city":"Kannur"}
print(my_dict)
# Out:
# {'name': 'Sinsina', 'Age': 20, 'city': 'Kannur'}

# %%
print(my_dict["city"])
# Out:
# Kannur

# %%
my_dict["Age"]=50
my_dict["email"]="sinsinav505@gmail.com"
print(my_dict)
# Out:
# {'name': 'Sinsina', 'Age': 50, 'city': 'Kannur', 'email': 'sinsinav505@gmail.com'}

# %%
del my_dict["city"]
print(my_dict)
# Out:
# {'name': 'Sinsina', 'Age': 50, 'email': 'sinsinav505@gmail.com'}

# %%
age=my_dict.pop("Age")
print(my_dict)
# Out:
# {'name': 'Sinsina', 'city': 'Kannur'}

# %%
my_dict={"name":"Sinsina","Age":20,"city":"Kannur"}
for key,value in my_dict.items():
  print(key,value)
# Out:
# name Sinsina
# Age 20
# city Kannur

# %%
is_equal=(10==10)
print(is_equal)
# Out:
# True

# %%
my_set={1,2,3,4,5}
print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
my_set.remove(3)
print(my_set)
# Out:
# {1, 2, 4, 5}

# %%
set1={1,2,3}
set2={3,4,5}
union_set=set1|set2
print(union_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
intersection_set=set1&set2
print(intersection_set)
difference_set=set1-set2
print(difference_set)
print(2 in my_set)
print(6 not in my_set)
# Out:
# {3}
# {1, 2}
# True
# True

# %%
x="Hello, World!"
print(x[0])
print(x[7:12])
y=x.split(",")
print(y)
z="-".join(y)
print(z)
# Out:
# H
# World
# ['Hello', ' World!']
# Hello- World!

# %%
lambda

# %%
mylist=[1,2,3,"orange","mango"]
print(mylist)
mylist[0]=20
print(mylist)
mylist.append(4)
print(mylist)
slist=mylist[1:4]
print(slist)
clist=mylist+[5,6]
print(clist)
mylist.extend(clist)
print(mylist)
mylist.remove(6)
print(mylist)
mylist.insert(0,50)
print(mylist)
mylist.pop(1)
print(mylist)
# Out:
# [1, 2, 3, 'orange', 'mango']
# [20, 2, 3, 'orange', 'mango']
# [20, 2, 3, 'orange', 'mango', 4]
# [2, 3, 'orange']
# [20, 2, 3, 'orange', 'mango', 4, 5, 6]
# [20, 2, 3, 'orange', 'mango', 4, 20, 2, 3, 'orange', 'mango', 4, 5, 6]
# [20, 2, 3, 'orange', 'mango', 4, 20, 2, 3, 'orange', 'mango', 4, 5]
# [50, 20, 2, 3, 'orange', 'mango', 4, 20, 2, 3, 'orange', 'mango', 4, 5]
# [50, 2, 3, 'orange', 'mango', 4, 20, 2, 3, 'orange', 'mango', 4, 5]

# %%
l1=[1,2,"ab"]
l2=["si",4,5]
l3=l1+l2
print(l3)
l4=["b","g","r","a","c"]
l4.sort()
print(l4)
# Out:
# [1, 2, 'ab', 'si', 4, 5]
# ['a', 'b', 'c', 'g', 'r']

# %%
mytuple=(1,2,3.4,'fg')
print(mytuple)
stuple=mytuple[0:3]
print(stuple)
ctuple=mytuple+(5,9)
print(ctuple)
# Out:
# (1, 2, 3.4, 'fg')
# (1, 2, 3.4)
# (1, 2, 3.4, 'fg', 5, 9)

# %%
t1=(1,2,3,"e")
t2=(5,6,7,"tt")
t3=t1+t2
print(t3)
# Out:
# (1, 2, 3, 'e', 5, 6, 7, 'tt')

# %%
d1={"name":"Sinsina","age":20,}
print(d1)
d1["place"]="Kannur"
print(d1)
del d1["place"]
print(d1)
print(d1["age"])
age=d1.pop("age")
print(d1)
# Out:
# {'name': 'Sinsina', 'age': 20}
# {'name': 'Sinsina', 'age': 20, 'place': 'Kannur'}
# {'name': 'Sinsina', 'age': 20}
# 20
# {'name': 'Sinsina'}

# %%
d2={"name":"Sinsina","age":20,"place":"kannur"}
for key in d2.keys():
  print(key)
# Out:
# name
# age
# place

# %%
d2={"name":"Sinsina","age":20}
for value in d2.values():
  print(value)
# Out:
# Sinsina
# 20

# %%
d2["name"]="Sin"
print(d2)
# Out:
# {'name': 'Sin', 'age': 20}

# %%
dict2={"name":"Sin","age":20}
print (type(dict2))
# Out:
# <class 'dict'>
